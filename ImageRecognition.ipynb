# %% [markdown]
# <a href="https://colab.research.google.com/github/adilAbbasov/Tensorflow/blob/main/ImageRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numphy

# %%
pip install opencv-python

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

filename = "images/lion.jpg"

img = image.load_img(filename, target_size = (224, 224))
plt.imshow(img)

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

resized_img = image.img_to_array(img)
final_img = np.expand_dims(resized_img, axis = 0)
final_img = tf.keras.applications.mobilenet_v2.preprocess_input(final_img)

predictions = mobile.predict(final_img)

from tensorflow.keras.applications import imagenet_utils
results = imagenet_utils.decode_predictions(predictions)

print(results)
# Out:
# 1/1 [==============================] - 1s 876ms/step
# [[('n02129165', 'lion', 0.9345183), ('n02125311', 'cougar', 0.0067227967), ('n02112137', 'chow', 0.0018742117), ('n02132136', 'brown_bear', 0.001710225), ('n02102480', 'Sussex_spaniel', 0.0014619349)]]
